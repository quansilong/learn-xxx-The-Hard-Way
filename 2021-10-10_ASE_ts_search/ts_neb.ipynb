# %%
# %run ts_neb_2Cu.py

from ase.io import read, iread
from ase.neb import NEBTools

neb_result = list(iread(traj_fname))
for i in neb_result:
    #print(i.get_potential_energy())
    pass
neb_result = NEBTools(neb_result)
neb_result.plot_band()
print(neb_result.get_barrier(), neb_result.get_fmax())
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 12:07:59        3.480165*       3.9808
# BFGSLineSearch:    1[  2] 12:07:59        3.181407*       0.0330
# [-0.08522439  0.          0.          2.08522439  0.          0.        ] 3.1814072639767277
# [-0.07670195  0.          0.          2.37670195  0.          0.        ] 3.6369826955859326
# [-0.06817951  0.          0.          2.66817951  0.          0.        ] 4.4394130333890764
# [-0.05965707  0.          0.          2.95965707  0.          0.        ] 5.190302266463356
# [-0.05113463  0.          0.          3.25113463  0.          0.        ] 5.778472992641284
# [-0.04261219  0.          0.          3.54261219  0.          0.        ] 6.2018073550941715
# [-0.03408976  0.          0.          3.83408976  0.          0.        ] 6.4918566083551426
# [-0.02556732  0.          0.          4.12556732  0.          0.        ] 6.684310161311052
# [-0.01704488  0.          0.          4.41704488  0.          0.        ] 6.809168152335575
# [-0.00852244  0.          0.          4.70852244  0.          0.        ] 6.888839255625118
# [0. 0. 0. 5. 0. 0.] 6.939039181478011
# (3.8385927388444543, 3.757631917501283) 3.855037356451095

# %%
# %run ts_neb_C2H6.py

from ase.io import read, iread
from ase.neb import NEBTools

#neb_result = list(iread(traj_fname))
neb_result = optimizer
for i in neb_result:
    #print(i.get_potential_energy())
    pass
neb_result = NEBTools(neb_result)
neb_result.plot_band()
print(neb_result.get_barrier(), neb_result.get_fmax())
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 13:35:11        3.078940*       4.0124
# BFGSLineSearch:    1[  1] 13:35:11        1.965828*       1.4235
# BFGSLineSearch:    2[  2] 13:35:11        1.688416*       3.1074
# BFGSLineSearch:    3[  4] 13:35:11        1.466516*       0.2986
# BFGSLineSearch:    4[  5] 13:35:11        1.462613*       0.0431
# Number of images per band guessed to be 11.
# Scaling axes.
# Processing band         14 /         15
# (0.01179075302489041, 2.220446049250313e-16) 0.5883965937100467
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9784/3347222985.py in <module>
#       6 #neb_result = list(iread(traj_fname))
#       7 neb_result = optimizer
# ----> 8 for i in neb_result:
#       9     #print(i.get_potential_energy())
#      10     pass
#
# TypeError: 'FIRE' object is not iterable
