# %%
file = { 'log' : r"./test_files/D-DNTAP.log",
         'chk' : r"./test_files/D-DNTAP.chk" }

with open(file['log'], "rt") as f:
    data = f.readlines()
    
with open(file['log'], "rt") as f:
    data2 = f.read()
    
print(type(data2 ))
data3 = data2.split("\n")
print(data3[-50:-1])


def is_Normal_termination(data):
    if "Normal" in data[-1]:
        return True
    else:
        return False
    
# for line in data[-5:]:
#     print(line)




    
is_Normal_termination(data)
# Out:
# <class 'str'>
# ...
